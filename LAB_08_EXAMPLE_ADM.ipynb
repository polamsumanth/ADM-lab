# %% [markdown]
# <a href="https://colab.research.google.com/github/polamsumanth/ADM-lab/blob/main/LAB_08_EXAMPLE_ADM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
data = pd.read_csv('/content/ADM_LAB_08.csv')
data.head()
# Out:
#       TV  RADIO  NEWSPAPER  SALES
# 0  230.0   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3

# %%
df = pd.DataFrame(data)
df.head()
# Out:
#       TV  RADIO  NEWSPAPER  SALES
# 0  230.0   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3

# %%
X = df[['TV','RADIO','NEWSPAPER']]
y = df['SALES']

# %%
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)

# %%
print(f"Coefficients: {model.coef_}")
print(f"Intercept: {model.intercept_}")
# Out:
# Coefficients: [0.06026421 0.0027217  0.02178718]
# Intercept: 6.6286779908009725

# %%
mse = mean_squared_error(y, y_pred)
r2 = r2_score(y, y_pred)

# %%
print(f"Mean Squared Error: {mse}")
print(f"R-Squared Score: {r2}")
# Out:
# Mean Squared Error: 9.466330862652142e-30
# R-Squared Score: 1.0

# %%
plt.figure(figsize=(6, 4))
plt.scatter(y, y_pred)
plt.xlabel("Actual Sales")
plt.ylabel("Predicted Sales")
plt.title("Actual vs. Predicted Sales")
plt.show()
